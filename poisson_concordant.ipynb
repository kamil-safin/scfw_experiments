# %%
import time
import scipy
import numpy as np
import numpy.matlib
from scipy.linalg import norm
from sklearn.datasets import load_svmlight_file
import matplotlib.pyplot as plt
from line_profiler import LineProfiler

# %%
W, y = load_svmlight_file('./data/a9a')
y = y.reshape(-1, 1)
W = W.toarray()

# %%
A = numpy.matlib.repmat(y, 1, W.shape[1]) * W
sA = np.sum(A, 1)
A[sA < 0, :] = -A[sA < 0, :]
A = A[sA != 0, :]
A = scipy.sparse.csr_matrix(A)

# %%
p = W.shape[1]
N = A.shape[0]

# %%
Bias = 1
b = (Bias * y).squeeze()
b = np.abs(b)
if (b.any == 0):
    print(' Input parameter y error')

# %%
lam = 1 / 2 * np.sqrt(N)
x = np.ones(p)
tols_main = 1e-10
alpha = 3
n_steps = 1000
terminate_tol = 1e-4
sub_tol = 0.25 * terminate_tol
steps_tol = 0.05
I = np.eye(p)
Iv = np.ones(p)
Mf = 2 * np.max(b**(-0.5))
R = 1
printst = 10

# %%
def fn_Poisson_Grad(x, A, b, lam):
    Btm = A.dot(x)  # Btm(i) = a_i^T x
    Par = 1 - b / Btm
    i = list(range(N))
    DPar = scipy.sparse.csr_matrix((Par, (i, i)), shape=(N, N))
    ResM = DPar.dot(A)
    l1_grad = np.array([1 if c >=0 else -1 for c in x])
    Grad = np.array(np.sum(ResM, axis=0)).squeeze() + lam * l1_grad
    return Grad, Btm

# %%
def fn_Poisson_Hinv(A, b, lam, Btmv):
    Rat = b / (Btmv)**2
    i = range(N)
    DRat = scipy.sparse.csr_matrix((Rat, (i, i)), shape=(N, N))
    Res1 = (A.T.dot(DRat)).dot(A)
    H = Res1
    H = H.A
    return H

# %%
def projection_simplex_sort(v, z=1):
    n_features = v.shape[0]
    u = np.sort(v)[::-1]
    cssv = np.cumsum(u) - z
    ind = np.arange(n_features) + 1
    cond = u - cssv / ind > 0
    rho = ind[cond][-1]
    theta = cssv[cond][-1] / float(rho)
    w = np.maximum(v - theta, 0)
    return w

def l1_ball_projection(y, z=R):
    if norm(y, 1) <= R:
        return y
    pos_proj = projection_simplex_sort(np.abs(y), z)
    return np.sign(y) * pos_proj

# %%
x_tmps = []

def fn_portf_fista(Grad, Hopr, x, L, tol):
    y = x.copy()
    x_cur = y.copy()
    t = 1
    kmax = 1200
    for k in range(1, kmax + 1):
        DQ = Hopr(y - x) + Grad
        x_tmp = y - 1 / L * DQ
        x_tmps.append(x_tmp)
        x_nxt = l1_ball_projection(x_tmp)
        xdiff = x_nxt - x_cur
        ndiff = norm(xdiff)
        if (ndiff < tol) and (k > 1):
            print('Fista err = %3.3e; Subiter = %3d; subproblem converged!\n' % (ndiff, k))
            break
        t_nxt = 0.5 * (1 + np.sqrt(1 + 4 * t**2))
        y = x_nxt + (t - 1) / t_nxt * xdiff
        t  = t_nxt
        x_cur = x_nxt
    return x_nxt

# %%
def fn_Poisson_Val(x, A, b, lam):
    Valb = A.dot(x)
    Valv = Valb - b * np.log(Valb)
    Val1 = np.sum(Valv)
    Val2 = lam / 2 * norm(x, 1)
    Val = Val1 + Val2
    return Val

# %%
Lest = 1

if Lest == 1:
    #Estimate Lipschitz Constant
    dirr = np.ones(p)
    Grad, Btmv = fn_Poisson_Grad(dirr, A, b, lam)
    H = fn_Poisson_Hinv(A, b, lam, Btmv)
    for Liter in range(1, 16):
        Dir = H.dot(dirr)
        dirr = Dir / norm(Dir)
    Hd = H.dot(dirr)
    dHd  = dirr.dot(Hd)
    L = dHd / (dirr.dot(dirr))

# %%
def run_concord(x):
    err, times, points = [], [], []
    Lest = 0
    s_deactive = 0
    points.append(x)

    int_start = time.time()
    for i in range(1, n_steps + 1):
        start = time.time()
        Grad, Btmv = fn_Poisson_Grad(x, A, b, lam)
        H = fn_Poisson_Hinv(A, b, lam, Btmv)
        # Evaluate the Hessian
        Hopr = lambda d: H.dot(d) # p by 1 vector
        if Lest == 0:
            # Compute Lipschitz Constant  
            dirr = np.ones(p)
            for Liter in range(1, 16):
                Dir = Hopr(dirr)
                dirr = Dir / norm(Dir)
            Hd = Hopr(dirr)
            dHd  = dirr.dot(Hd)
            L = dHd / (dirr.dot(dirr))
        x_nxt = fn_portf_fista(Grad, Hopr, x, L, sub_tol)
        diffx = x_nxt - x
        # solution value stop-criterion    
        nrm_dx = norm(diffx)
        rdiff = nrm_dx / max(1.0, norm(x))
        err.append(rdiff)
        # Check the stopping criterion.
        if (rdiff <= terminate_tol) and i > 1:
            int_end = time.time()
            print('Convergence achieved!')
            print('iter = %4d, stepsize = %3.3e, rdiff = %3.3e\n' % (i, s, rdiff))
            print('Total time: %f' % (int_end - int_start))
            return points
        # Compute a step-size if required.
        if not s_deactive:
            Hd = Hopr(diffx)
            dHd = diffx.dot(Hd)
            lams = np.sqrt(dHd)
            s = 1 / (1 + lams)   # 0.5 * Mf = 1 
        if (1 - s <= steps_tol):
            s = 1
            s_deactive = 1               
        x = x + s * diffx
        end = time.time()
        times.append(end - start)
        points.append(x)
        if (i % printst == 0) or (i == 1):
            print('iter = %4d, stepsize = %3.3e, rdiff = %3.3e\n' % (i, s, rdiff))
    # if mod(iter, options.printst) ~= 0
    #     fprintf('iter = %4d, stepsize = %3.3e, rdiff = %3.3e\n', iter, s, rdiff);
    # end
    int_end = time.time()
    if i >= n_steps:
        print('Exceed the maximum number of iterations')
        print('Total time: %f' % (int_end - int_start))
    return points

# %%
lp = LineProfiler()
lp_wrapper = lp(run_concord)
points = lp_wrapper(x)
# Out:
# Fista err = 0.000e+00; Subiter =   2; subproblem converged!
#
# iter =    1, stepsize = 5.158e-03, rdiff = 1.012e+00
#
# Fista err = 0.000e+00; Subiter =   2; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   2; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   2; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   2; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   2; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   2; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# iter =   10, stepsize = 5.141e-03, rdiff = 1.013e+00
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# iter =   20, stepsize = 5.121e-03, rdiff = 1.013e+00
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# iter =   30, stepsize = 5.100e-03, rdiff = 1.013e+00
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# iter =   40, stepsize = 5.079e-03, rdiff = 1.014e+00
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# iter =   50, stepsize = 5.056e-03, rdiff = 1.014e+00
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# iter =   60, stepsize = 5.032e-03, rdiff = 1.015e+00
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# iter =   70, stepsize = 5.007e-03, rdiff = 1.015e+00
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# iter =   80, stepsize = 4.981e-03, rdiff = 1.015e+00
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# iter =   90, stepsize = 4.954e-03, rdiff = 1.015e+00
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   3; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# iter =  100, stepsize = 4.925e-03, rdiff = 1.016e+00
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# iter =  110, stepsize = 4.896e-03, rdiff = 1.016e+00
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# iter =  120, stepsize = 4.864e-03, rdiff = 1.016e+00
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# iter =  130, stepsize = 4.832e-03, rdiff = 1.016e+00
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   4; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   5; subproblem converged!
#
# iter =  140, stepsize = 4.798e-03, rdiff = 1.016e+00
#
# Fista err = 0.000e+00; Subiter =   5; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   5; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   5; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   5; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   5; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   5; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   5; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   5; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   5; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   5; subproblem converged!
#
# iter =  150, stepsize = 4.763e-03, rdiff = 1.016e+00
#
# Fista err = 0.000e+00; Subiter =   5; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   5; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   5; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   5; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   6; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   6; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   6; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   6; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   6; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   6; subproblem converged!
#
# iter =  160, stepsize = 4.726e-03, rdiff = 1.016e+00
#
# Fista err = 0.000e+00; Subiter =   6; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   6; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   6; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   6; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   6; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   6; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   6; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   6; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   6; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   6; subproblem converged!
#
# iter =  170, stepsize = 4.687e-03, rdiff = 1.016e+00
#
# Fista err = 0.000e+00; Subiter =   6; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   6; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   6; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   6; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   6; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   6; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   7; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   7; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   7; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   7; subproblem converged!
#
# iter =  180, stepsize = 4.647e-03, rdiff = 1.016e+00
#
# Fista err = 0.000e+00; Subiter =   7; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   7; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   7; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   7; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   7; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   7; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   7; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   7; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   7; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   7; subproblem converged!
#
# iter =  190, stepsize = 4.606e-03, rdiff = 1.015e+00
#
# Fista err = 0.000e+00; Subiter =   7; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   8; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   8; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   8; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   8; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   8; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   8; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   8; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   8; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   8; subproblem converged!
#
# iter =  200, stepsize = 4.563e-03, rdiff = 1.014e+00
#
# Fista err = 0.000e+00; Subiter =   8; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   9; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   9; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   9; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   9; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   9; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   9; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   9; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =   9; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =  10; subproblem converged!
#
# iter =  210, stepsize = 4.518e-03, rdiff = 1.014e+00
#
# Fista err = 0.000e+00; Subiter =  10; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =  10; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =  10; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =  10; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =  10; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =  11; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =  11; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =  11; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =  11; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =  11; subproblem converged!
#
# iter =  220, stepsize = 4.472e-03, rdiff = 1.013e+00
#
# Fista err = 0.000e+00; Subiter =  12; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =  12; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =  12; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =  12; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =  13; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =  13; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =  13; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =  14; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =  14; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =  15; subproblem converged!
#
# iter =  230, stepsize = 4.423e-03, rdiff = 1.012e+00
#
# Fista err = 0.000e+00; Subiter =  15; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =  16; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =  16; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =  17; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =  18; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =  19; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =  20; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =  21; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =  22; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =  24; subproblem converged!
#
# iter =  240, stepsize = 4.374e-03, rdiff = 1.010e+00
#
# Fista err = 0.000e+00; Subiter =  26; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =  28; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =  32; subproblem converged!
#
# Fista err = 0.000e+00; Subiter =  39; subproblem converged!
#
# Fista err = 1.990e-05; Subiter = 118; subproblem converged!
#
# Fista err = 1.636e-05; Subiter = 118; subproblem converged!
#
# Fista err = 1.967e-05; Subiter =  85; subproblem converged!
#
# Fista err = 1.693e-05; Subiter =  52; subproblem converged!
#
# Fista err = 1.219e-05; Subiter =  51; subproblem converged!
# Fista err = 1.134e-05; Subiter =  51; subproblem converged!
#
# iter =  250, stepsize = 4.330e-03, rdiff = 1.007e+00
#
# Fista err = 1.617e-05; Subiter =  52; subproblem converged!
#
# Fista err = 2.378e-05; Subiter =  52; subproblem converged!
#
# Fista err = 1.328e-05; Subiter =  86; subproblem converged!
#
# Fista err = 1.446e-05; Subiter =  86; subproblem converged!
#
# Fista err = 1.453e-05; Subiter =  86; subproblem converged!
#
# Fista err = 1.347e-05; Subiter =  86; subproblem converged!
#
# Fista err = 1.129e-05; Subiter =  86; subproblem converged!
#
# Fista err = 8.079e-06; Subiter =  86; subproblem converged!
#
# Fista err = 3.760e-06; Subiter =  86; subproblem converged!
#
# Fista err = 1.677e-06; Subiter =  86; subproblem converged!
#
# iter =  260, stepsize = 4.286e-03, rdiff = 1.010e+00
#
# Fista err = 1.828e-05; Subiter =  52; subproblem converged!
#
# Fista err = 9.324e-06; Subiter =  52; subproblem converged!
#
# Fista err = 9.770e-07; Subiter =  52; subproblem converged!
#
# Fista err = 1.270e-05; Subiter =  52; subproblem converged!
#
# Fista err = 1.343e-05; Subiter = 153; subproblem converged!
#
# Fista err = 8.977e-06; Subiter = 153; subproblem converged!
#
# Fista err = 2.252e-05; Subiter = 120; subproblem converged!
#
# Fista err = 1.644e-05; Subiter = 120; subproblem converged!
#
# Fista err = 1.025e-05; Subiter = 120; subproblem converged!
#
# Fista err = 2.432e-06; Subiter = 120; subproblem converged!
#
# iter =  270, stepsize = 4.240e-03, rdiff = 1.019e+00
#
# Fista err = 2.440e-05; Subiter = 229; subproblem converged!
#
# Fista err = 1.242e-05; Subiter = 229; subproblem converged!
#
# Fista err = 1.711e-05; Subiter = 229; subproblem converged!
#
# Fista err = 2.225e-05; Subiter = 229; subproblem converged!
#
# Fista err = 6.851e-06; Subiter = 230; subproblem converged!
#
# Fista err = 3.152e-06; Subiter = 230; subproblem converged!
#
# Fista err = 3.722e-06; Subiter = 230; subproblem converged!
#
# Fista err = 8.423e-06; Subiter = 230; subproblem converged!
#
# Fista err = 1.393e-05; Subiter = 230; subproblem converged!
#
# Fista err = 1.989e-05; Subiter = 230; subproblem converged!
#
# iter =  280, stepsize = 4.202e-03, rdiff = 1.034e+00
#
# Fista err = 1.634e-05; Subiter = 231; subproblem converged!
#
# Fista err = 2.168e-05; Subiter = 196; subproblem converged!
#
# Fista err = 1.897e-05; Subiter = 196; subproblem converged!
#
# Fista err = 2.080e-05; Subiter = 196; subproblem converged!
#
# Fista err = 7.526e-06; Subiter = 231; subproblem converged!
#
# Fista err = 1.255e-05; Subiter = 230; subproblem converged!
#
# Fista err = 2.042e-05; Subiter = 225; subproblem converged!
#
# Fista err = 1.997e-05; Subiter = 291; subproblem converged!
#
# Fista err = 1.952e-05; Subiter = 188; subproblem converged!
#
# Fista err = 1.844e-05; Subiter =  82; subproblem converged!
#
# iter =  290, stepsize = 4.159e-03, rdiff = 1.057e+00
#
# Fista err = 1.703e-05; Subiter =  54; subproblem converged!
#
# Fista err = 6.182e-06; Subiter =  54; subproblem converged!
#
# Fista err = 1.893e-06; Subiter =  54; subproblem converged!
#
# Fista err = 3.661e-06; Subiter =  54; subproblem converged!
#
# Fista err = 1.191e-05; Subiter =  54; subproblem converged!
#
# Fista err = 1.256e-05; Subiter =  82; subproblem converged!
#
# Fista err = 3.317e-06; Subiter =  82; subproblem converged!
#
# Fista err = 7.143e-06; Subiter =  82; subproblem converged!
#
# Fista err = 1.733e-05; Subiter =  81; subproblem converged!
#
# Fista err = 2.431e-05; Subiter = 256; subproblem converged!
#
# iter =  300, stepsize = 4.103e-03, rdiff = 1.056e+00
#
# Fista err = 1.435e-05; Subiter =  96; subproblem converged!
#
# Fista err = 2.138e-05; Subiter =  96; subproblem converged!
#
# Fista err = 2.480e-05; Subiter =  96; subproblem converged!
#
# Fista err = 2.387e-05; Subiter =  96; subproblem converged!
#
# Fista err = 2.133e-05; Subiter =  96; subproblem converged!
#
# Fista err = 1.587e-05; Subiter =  96; subproblem converged!
#
# Fista err = 2.028e-05; Subiter = 241; subproblem converged!
#
# Fista err = 2.161e-05; Subiter = 218; subproblem converged!
#
# Fista err = 2.471e-05; Subiter = 217; subproblem converged!
#
# Fista err = 2.430e-05; Subiter = 217; subproblem converged!
#
# iter =  310, stepsize = 4.079e-03, rdiff = 1.048e+00
#
# Fista err = 2.405e-05; Subiter = 217; subproblem converged!
#
# Fista err = 2.402e-05; Subiter = 217; subproblem converged!
#
# Fista err = 2.418e-05; Subiter = 217; subproblem converged!
#
# Fista err = 2.281e-05; Subiter = 217; subproblem converged!
#
# Fista err = 2.437e-05; Subiter = 220; subproblem converged!
#
# Fista err = 2.382e-05; Subiter = 239; subproblem converged!
#
# Fista err = 2.387e-05; Subiter = 238; subproblem converged!
#
# Fista err = 2.443e-05; Subiter = 236; subproblem converged!
#
# Fista err = 2.421e-05; Subiter = 236; subproblem converged!
#
# Fista err = 2.391e-05; Subiter = 236; subproblem converged!
#
# iter =  320, stepsize = 4.144e-03, rdiff = 1.045e+00
#
# Fista err = 2.335e-05; Subiter = 236; subproblem converged!
#
# Fista err = 2.410e-05; Subiter = 157; subproblem converged!
#
# Fista err = 1.644e-05; Subiter = 157; subproblem converged!
#
# Fista err = 1.790e-05; Subiter = 157; subproblem converged!
#
# Fista err = 1.890e-05; Subiter = 158; subproblem converged!
#
# Fista err = 1.986e-05; Subiter = 186; subproblem converged!
#
# Fista err = 2.241e-05; Subiter = 186; subproblem converged!
#
# Fista err = 2.168e-05; Subiter = 187; subproblem converged!
#
# Fista err = 1.858e-05; Subiter = 188; subproblem converged!
#
# Fista err = 1.919e-05; Subiter = 189; subproblem converged!
#
# iter =  330, stepsize = 4.534e-03, rdiff = 1.053e+00
#
# Fista err = 2.005e-05; Subiter = 190; subproblem converged!
#
# Fista err = 2.162e-05; Subiter = 191; subproblem converged!
#
# Fista err = 2.397e-05; Subiter = 193; subproblem converged!
#
# Fista err = 2.138e-05; Subiter = 249; subproblem converged!
#
# Fista err = 2.476e-05; Subiter = 188; subproblem converged!
#
# Fista err = 2.113e-05; Subiter = 191; subproblem converged!
#
# Fista err = 2.460e-05; Subiter = 193; subproblem converged!
#
# Fista err = 2.026e-05; Subiter = 194; subproblem converged!
#
# Fista err = 1.223e-05; Subiter = 197; subproblem converged!
#
# Fista err = 2.200e-05; Subiter = 200; subproblem converged!
#
# iter =  340, stepsize = 4.960e-03, rdiff = 1.081e+00
#
# Fista err = 2.433e-05; Subiter = 296; subproblem converged!
#
# Fista err = 2.499e-05; Subiter = 302; subproblem converged!
#
# Fista err = 2.349e-05; Subiter = 326; subproblem converged!
#
# Fista err = 2.414e-05; Subiter = 408; subproblem converged!
#
# Fista err = 2.386e-05; Subiter = 261; subproblem converged!
#
# Fista err = 5.297e-06; Subiter = 261; subproblem converged!
#
# Fista err = 1.999e-05; Subiter = 382; subproblem converged!
#
# Fista err = 2.198e-05; Subiter = 398; subproblem converged!
#
# Fista err = 1.543e-05; Subiter = 402; subproblem converged!
#
# Fista err = 1.988e-05; Subiter = 350; subproblem converged!
#
# iter =  350, stepsize = 5.431e-03, rdiff = 1.084e+00
#
# Fista err = 2.047e-05; Subiter = 298; subproblem converged!
#
# Fista err = 2.284e-05; Subiter = 298; subproblem converged!
#
# Fista err = 1.838e-05; Subiter = 297; subproblem converged!
#
# Fista err = 1.781e-05; Subiter = 297; subproblem converged!
#
# Fista err = 2.391e-05; Subiter = 297; subproblem converged!
#
# Fista err = 2.207e-05; Subiter = 348; subproblem converged!
#
# Fista err = 2.229e-05; Subiter = 295; subproblem converged!
#
# Fista err = 2.332e-05; Subiter = 348; subproblem converged!
#
# Fista err = 2.438e-05; Subiter = 398; subproblem converged!
#
# Fista err = 2.442e-05; Subiter = 390; subproblem converged!
#
# iter =  360, stepsize = 6.068e-03, rdiff = 1.068e+00
#
# Fista err = 2.487e-05; Subiter = 360; subproblem converged!
#
# Fista err = 2.422e-05; Subiter = 363; subproblem converged!
#
# Fista err = 2.332e-05; Subiter = 365; subproblem converged!
#
# Fista err = 2.410e-05; Subiter = 364; subproblem converged!
#
# Fista err = 2.452e-05; Subiter = 415; subproblem converged!
#
# Fista err = 2.496e-05; Subiter = 463; subproblem converged!
#
# Fista err = 2.171e-05; Subiter = 464; subproblem converged!
#
# Fista err = 2.393e-05; Subiter = 463; subproblem converged!
#
# Fista err = 2.168e-05; Subiter = 463; subproblem converged!
#
# Fista err = 2.265e-05; Subiter = 454; subproblem converged!
#
# iter =  370, stepsize = 6.829e-03, rdiff = 1.088e+00
#
# Fista err = 2.448e-05; Subiter = 396; subproblem converged!
#
# Fista err = 2.435e-05; Subiter = 419; subproblem converged!
#
# Fista err = 2.474e-05; Subiter = 419; subproblem converged!
# Fista err = 2.467e-05; Subiter = 394; subproblem converged!
#
# Fista err = 2.419e-05; Subiter = 391; subproblem converged!
#
# Fista err = 2.454e-05; Subiter = 362; subproblem converged!
#
# Fista err = 2.477e-05; Subiter = 363; subproblem converged!
#
# Fista err = 2.356e-05; Subiter = 393; subproblem converged!
#
# Fista err = 2.434e-05; Subiter = 356; subproblem converged!
#
# Fista err = 2.430e-05; Subiter = 322; subproblem converged!
#
# iter =  380, stepsize = 7.675e-03, rdiff = 1.108e+00
#
# Fista err = 2.375e-05; Subiter = 356; subproblem converged!
#
# Fista err = 2.377e-05; Subiter = 361; subproblem converged!
#
# Fista err = 2.405e-05; Subiter = 400; subproblem converged!
#
# Fista err = 2.484e-05; Subiter = 375; subproblem converged!
#
# Fista err = 2.484e-05; Subiter = 374; subproblem converged!
#
# Fista err = 2.360e-05; Subiter = 375; subproblem converged!
#
# Fista err = 2.273e-05; Subiter = 376; subproblem converged!
#
# Fista err = 2.162e-05; Subiter = 376; subproblem converged!
#
# Fista err = 2.393e-05; Subiter = 407; subproblem converged!
#
# Fista err = 2.259e-05; Subiter = 460; subproblem converged!
#
# iter =  390, stepsize = 8.686e-03, rdiff = 1.120e+00
#
# Fista err = 2.371e-05; Subiter = 551; subproblem converged!
#
# Fista err = 2.472e-05; Subiter = 420; subproblem converged!
#
# Fista err = 2.478e-05; Subiter = 711; subproblem converged!
#
# Fista err = 2.470e-05; Subiter = 643; subproblem converged!
#
# Fista err = 2.485e-05; Subiter = 579; subproblem converged!
#
# Fista err = 2.486e-05; Subiter = 631; subproblem converged!
#
# Fista err = 2.440e-05; Subiter = 580; subproblem converged!
#
# Fista err = 2.300e-05; Subiter = 520; subproblem converged!
#
# Fista err = 2.453e-05; Subiter = 642; subproblem converged!
#
# Fista err = 2.416e-05; Subiter = 487; subproblem converged!
#
# iter =  400, stepsize = 1.007e-02, rdiff = 1.120e+00
#
# Fista err = 2.096e-05; Subiter = 358; subproblem converged!
#
# Fista err = 2.491e-05; Subiter = 352; subproblem converged!
#
# Fista err = 2.332e-05; Subiter = 318; subproblem converged!
#
# Fista err = 1.697e-05; Subiter = 265; subproblem converged!
#
# Fista err = 2.486e-05; Subiter = 226; subproblem converged!
#
# Fista err = 2.150e-05; Subiter = 257; subproblem converged!
#
# Fista err = 1.459e-05; Subiter = 254; subproblem converged!
#
# Fista err = 2.310e-05; Subiter = 721; subproblem converged!
#
# Fista err = 2.422e-05; Subiter = 458; subproblem converged!
#
# Fista err = 2.483e-05; Subiter = 385; subproblem converged!
#
# iter =  410, stepsize = 1.161e-02, rdiff = 1.027e+00
#
# Fista err = 2.498e-05; Subiter = 322; subproblem converged!
#
# Fista err = 2.178e-05; Subiter = 191; subproblem converged!
#
# Fista err = 1.955e-05; Subiter = 191; subproblem converged!
#
# Fista err = 2.349e-05; Subiter = 191; subproblem converged!
#
# Fista err = 2.273e-05; Subiter = 191; subproblem converged!
#
# Fista err = 2.052e-05; Subiter = 191; subproblem converged!
#
# Fista err = 1.875e-05; Subiter = 191; subproblem converged!
#
# Fista err = 2.463e-05; Subiter = 190; subproblem converged!
#
# Fista err = 2.102e-05; Subiter = 191; subproblem converged!
#
# Fista err = 2.262e-05; Subiter = 191; subproblem converged!
#
# iter =  420, stepsize = 1.354e-02, rdiff = 1.025e+00
#
# Fista err = 2.394e-05; Subiter = 191; subproblem converged!
#
# Fista err = 2.374e-05; Subiter = 216; subproblem converged!
#
# Fista err = 2.286e-05; Subiter = 216; subproblem converged!
#
# Fista err = 2.177e-05; Subiter = 216; subproblem converged!
#
# Fista err = 2.399e-05; Subiter = 215; subproblem converged!
#
# Fista err = 2.261e-05; Subiter = 215; subproblem converged!
#
# Fista err = 2.119e-05; Subiter = 215; subproblem converged!
#
# Fista err = 2.387e-05; Subiter = 214; subproblem converged!
#
# Fista err = 2.204e-05; Subiter = 214; subproblem converged!
#
# Fista err = 2.024e-05; Subiter = 214; subproblem converged!
#
# iter =  430, stepsize = 1.591e-02, rdiff = 1.029e+00
#
# Fista err = 2.313e-05; Subiter = 213; subproblem converged!
#
# Fista err = 2.101e-05; Subiter = 213; subproblem converged!
#
# Fista err = 2.426e-05; Subiter = 212; subproblem converged!
#
# Fista err = 2.487e-05; Subiter = 188; subproblem converged!
#
# Fista err = 2.359e-05; Subiter = 187; subproblem converged!
#
# Fista err = 2.467e-05; Subiter = 188; subproblem converged!
#
# Fista err = 2.443e-05; Subiter = 187; subproblem converged!
#
# Fista err = 2.320e-05; Subiter = 186; subproblem converged!
#
# Fista err = 2.058e-05; Subiter = 185; subproblem converged!
#
# Fista err = 2.478e-05; Subiter = 224; subproblem converged!
#
# iter =  440, stepsize = 1.900e-02, rdiff = 8.868e-01
#
# Fista err = 1.958e-05; Subiter = 201; subproblem converged!
#
# Fista err = 2.386e-05; Subiter = 199; subproblem converged!
#
# Fista err = 1.975e-05; Subiter = 108; subproblem converged!
#
# Fista err = 2.190e-05; Subiter = 196; subproblem converged!
#
# Fista err = 2.453e-05; Subiter = 195; subproblem converged!
#
# Fista err = 2.092e-05; Subiter = 195; subproblem converged!
#
# Fista err = 2.354e-05; Subiter = 194; subproblem converged!
#
# Fista err = 2.165e-05; Subiter = 194; subproblem converged!
#
# Fista err = 2.378e-05; Subiter = 193; subproblem converged!
#
# Fista err = 2.343e-05; Subiter = 193; subproblem converged!
#
# iter =  450, stepsize = 2.225e-02, rdiff = 7.271e-01
#
# Fista err = 2.466e-05; Subiter = 193; subproblem converged!
#
# Fista err = 2.483e-05; Subiter = 215; subproblem converged!
#
# Fista err = 1.982e-05; Subiter = 215; subproblem converged!
#
# Fista err = 2.049e-05; Subiter = 214; subproblem converged!
#
# Fista err = 2.112e-05; Subiter = 213; subproblem converged!
#
# Fista err = 2.168e-05; Subiter = 212; subproblem converged!
#
# Fista err = 2.215e-05; Subiter = 211; subproblem converged!
#
# Fista err = 2.252e-05; Subiter = 210; subproblem converged!
#
# Fista err = 2.279e-05; Subiter = 209; subproblem converged!
#
# Fista err = 2.294e-05; Subiter = 208; subproblem converged!
#
# iter =  460, stepsize = 2.665e-02, rdiff = 5.730e-01
#
# Fista err = 2.297e-05; Subiter = 207; subproblem converged!
#
# Fista err = 2.287e-05; Subiter = 206; subproblem converged!
#
# Fista err = 2.266e-05; Subiter = 205; subproblem converged!
#
# Fista err = 2.440e-05; Subiter = 203; subproblem converged!
#
# Fista err = 2.368e-05; Subiter = 202; subproblem converged!
#
# Fista err = 2.475e-05; Subiter = 149; subproblem converged!
#
# Fista err = 2.179e-05; Subiter = 149; subproblem converged!
#
# Fista err = 2.152e-05; Subiter = 148; subproblem converged!
#
# Fista err = 2.211e-05; Subiter = 147; subproblem converged!
#
# Fista err = 2.334e-05; Subiter = 146; subproblem converged!
#
# iter =  470, stepsize = 3.333e-02, rdiff = 4.265e-01
#
# Fista err = 2.498e-05; Subiter = 145; subproblem converged!
#
# Fista err = 2.150e-05; Subiter = 145; subproblem converged!
#
# Fista err = 2.306e-05; Subiter = 144; subproblem converged!
#
# Fista err = 2.478e-05; Subiter = 143; subproblem converged!
#
# Fista err = 2.180e-05; Subiter = 143; subproblem converged!
#
# Fista err = 2.329e-05; Subiter = 142; subproblem converged!
#
# Fista err = 2.477e-05; Subiter = 141; subproblem converged!
#
# Fista err = 2.220e-05; Subiter = 141; subproblem converged!
#
# Fista err = 2.335e-05; Subiter = 140; subproblem converged!
#
# Fista err = 2.450e-05; Subiter = 139; subproblem converged!
#
# iter =  480, stepsize = 4.499e-02, rdiff = 2.898e-01
#
# Fista err = 2.231e-05; Subiter = 139; subproblem converged!
#
# Fista err = 2.326e-05; Subiter = 138; subproblem converged!
#
# Fista err = 2.405e-05; Subiter = 137; subproblem converged!
#
# Fista err = 2.475e-05; Subiter = 136; subproblem converged!
#
# Fista err = 2.270e-05; Subiter = 136; subproblem converged!
#
# Fista err = 2.332e-05; Subiter = 135; subproblem converged!
#
# Fista err = 2.379e-05; Subiter = 134; subproblem converged!
#
# Fista err = 2.393e-05; Subiter = 133; subproblem converged!
#
# Fista err = 2.470e-05; Subiter = 120; subproblem converged!
#
# Fista err = 2.420e-05; Subiter = 118; subproblem converged!
#
# iter =  490, stepsize = 7.076e-02, rdiff = 1.651e-01
#
# Fista err = 2.397e-05; Subiter = 117; subproblem converged!
#
# Fista err = 2.378e-05; Subiter = 116; subproblem converged!
#
# Fista err = 2.343e-05; Subiter = 115; subproblem converged!
#
# Fista err = 2.447e-05; Subiter = 113; subproblem converged!
#
# Fista err = 2.461e-05; Subiter = 111; subproblem converged!
#
# Fista err = 2.414e-05; Subiter =  97; subproblem converged!
#
# Fista err = 2.432e-05; Subiter =  94; subproblem converged!
# Fista err = 2.415e-05; Subiter =  92; subproblem converged!
#
# Fista err = 2.339e-05; Subiter =  74; subproblem converged!
#
# Fista err = 2.257e-05; Subiter =  73; subproblem converged!
#
# iter =  500, stepsize = 1.700e-01, rdiff = 5.618e-02
#
# Fista err = 2.199e-05; Subiter =  72; subproblem converged!
#
# Fista err = 2.253e-05; Subiter =  55; subproblem converged!
#
# Fista err = 2.073e-05; Subiter =  54; subproblem converged!
#
# Fista err = 2.235e-05; Subiter =  52; subproblem converged!
#
# Fista err = 2.265e-05; Subiter =  49; subproblem converged!
#
# Fista err = 2.489e-05; Subiter =  30; subproblem converged!
#
# Fista err = 2.362e-05; Subiter =  22; subproblem converged!
#
# Fista err = 5.517e-06; Subiter =   2; subproblem converged!
#
# Fista err = 5.197e-06; Subiter =   2; subproblem converged!
#
# Convergence achieved!
# iter =  509, stepsize = 9.397e-01, rdiff = 3.699e-05
#
# Total time: 30.698376

# %%
lp.print_stats()
# Out:
# Timer unit: 3.0047e-07 s
#
# Total time: 6.54942 s
# File: <ipython-input-13-a5a38ad2ab82>
# Function: run_concord at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def run_concord(x):
#      2         1          6.0      6.0      0.0      err, times, points = [], [], []
#      3         1          3.0      3.0      0.0      Lest = 0
#      4         1          3.0      3.0      0.0      s_deactive = 0
#      5         1          4.0      4.0      0.0      points.append(x)
#      6
#      7         1          4.0      4.0      0.0      int_start = time.time()
#      8       230        643.0      2.8      0.0      for i in range(1, n_steps + 1):
#      9       230        722.0      3.1      0.0          start = time.time()
#     10       230    2165683.0   9416.0      9.9          Grad, Btmv = fn_Poisson_Grad(x, A, b, lam)
#     11       230    5377471.0  23380.3     24.7          H = fn_Poisson_Hinv(A, b, lam, Btmv)
#     12                                                   # Evaluate the Hessian
#     13       230       1947.0      8.5      0.0          Hopr = lambda d: H.dot(d) # p by 1 vector
#     14       230        687.0      3.0      0.0          if Lest == 0:
#     15                                                       # Compute Lipschitz Constant
#     16       230      10592.0     46.1      0.0              dirr = np.ones(p)
#     17      3680      11899.0      3.2      0.1              for Liter in range(1, 16):
#     18      3450      96236.0     27.9      0.4                  Dir = Hopr(dirr)
#     19      3450     333283.0     96.6      1.5                  dirr = Dir / norm(Dir)
#     20       230       5444.0     23.7      0.0              Hd = Hopr(dirr)
#     21       230       3111.0     13.5      0.0              dHd  = dirr.dot(Hd)
#     22       230       1877.0      8.2      0.0              L = dHd / (dirr.dot(dirr))
#     23       230   13685686.0  59503.0     62.8          x_nxt = fn_portf_fista(Grad, Hopr, x, L, sub_tol)
#     24       230       3822.0     16.6      0.0          diffx = x_nxt - x
#     25                                                   # solution value stop-criterion
#     26       230      27076.0    117.7      0.1          nrm_dx = norm(diffx)
#     27       230      19567.0     85.1      0.1          rdiff = nrm_dx / max(1.0, norm(x))
#     28       230        857.0      3.7      0.0          err.append(rdiff)
#     29                                                   # Check the stopping criterion.
#     30       230        834.0      3.6      0.0          if (rdiff <= terminate_tol) and i > 1:
#     31         1          6.0      6.0      0.0              int_end = time.time()
#     32         1        601.0    601.0      0.0              print('Convergence achieved!')
#     33         1        555.0    555.0      0.0              print('iter = %4d, stepsize = %3.3e, rdiff = %3.3e\n' % (i, s, rdiff))
#     34         1        625.0    625.0      0.0              print('Total time: %f' % (int_end - int_start))
#     35         1          4.0      4.0      0.0              return points
#     36                                                   # Compute a step-size if required.
#     37       229        615.0      2.7      0.0          if not s_deactive:
#     38       229      13222.0     57.7      0.1              Hd = Hopr(diffx)
#     39       229       5844.0     25.5      0.0              dHd = diffx.dot(Hd)
#     40       229       3821.0     16.7      0.0              lams = np.sqrt(dHd)
#     41       229       2075.0      9.1      0.0              s = 1 / (1 + lams)   # 0.5 * Mf = 1
#     42       229       1421.0      6.2      0.0          if (1 - s <= steps_tol):
#     43         1          3.0      3.0      0.0              s = 1
#     44         1          2.0      2.0      0.0              s_deactive = 1
#     45       229       3753.0     16.4      0.0          x = x + s * diffx
#     46       229       1334.0      5.8      0.0          end = time.time()
#     47       229        922.0      4.0      0.0          times.append(end - start)
#     48       229        706.0      3.1      0.0          points.append(x)
#     49       229       1054.0      4.6      0.0          if (i % printst == 0) or (i == 1):
#     50        23      13265.0    576.7      0.1              print('iter = %4d, stepsize = %3.3e, rdiff = %3.3e\n' % (i, s, rdiff))
#     51                                               # if mod(iter, options.printst) ~= 0
#     52                                               #     fprintf('iter = %4d, stepsize = %3.3e, rdiff = %3.3e\n', iter, s, rdiff);
#     53                                               # end
#     54                                               int_end = time.time()
#     55                                               if i >= n_steps:
#     56                                                   print('Exceed the maximum number of iterations')
#     57                                                   print('Total time: %f' % (int_end - int_start))
#     58                                               return points

# %%
vals = [fn_Poisson_Val(x, A, b, lam) for x in points[:-1]]
plt.plot(vals)
plt.show()

# %%
vals[-1]

# %%
points[-1]
